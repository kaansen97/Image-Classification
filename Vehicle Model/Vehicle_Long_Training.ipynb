# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['Boat', 'Bus', 'Cycle','Helicopter','Truck']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['Train', 'Test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading Train
# 100%|██████████| 48/48 [00:00<00:00, 1456.99it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1414.13it/s]
# 100%|██████████| 60/60 [00:00<00:00, 1466.10it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1456.94it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1550.83it/s]
# Loading Test
# 100%|██████████| 5/5 [00:00<00:00, 1253.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1253.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1255.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1002.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1253.00it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 252
# Number of testing examples: 25
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0,0,0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ##Scale the Data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# ##Create Simple Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=30, validation_split = 0.2)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.7267 - accuracy: 0.7562 - val_loss: 1.1909 - val_accuracy: 0.6078
# Epoch 2/30
# 2/2 [==============================] - 2s 934ms/step - loss: 0.7045 - accuracy: 0.7512 - val_loss: 1.2381 - val_accuracy: 0.5490
# Epoch 3/30
# 2/2 [==============================] - 2s 918ms/step - loss: 0.7039 - accuracy: 0.7512 - val_loss: 1.1599 - val_accuracy: 0.6667
# Epoch 4/30
# 2/2 [==============================] - 2s 914ms/step - loss: 0.6509 - accuracy: 0.7662 - val_loss: 1.3046 - val_accuracy: 0.5882
# Epoch 5/30
# 2/2 [==============================] - 2s 925ms/step - loss: 0.6521 - accuracy: 0.7562 - val_loss: 1.1985 - val_accuracy: 0.5490
# Epoch 6/30
# 2/2 [==============================] - 2s 923ms/step - loss: 0.5943 - accuracy: 0.8010 - val_loss: 1.1801 - val_accuracy: 0.6275
# Epoch 7/30
# 2/2 [==============================] - 2s 898ms/step - loss: 0.5725 - accuracy: 0.8010 - val_loss: 1.1989 - val_accuracy: 0.6471
# Epoch 8/30
# 2/2 [==============================] - 2s 989ms/step - loss: 0.5469 - accuracy: 0.8159 - val_loss: 1.2885 - val_accuracy: 0.5686
# Epoch 9/30
# 2/2 [==============================] - 2s 931ms/step - loss: 0.5489 - accuracy: 0.7910 - val_loss: 1.2234 - val_accuracy: 0.5490
# Epoch 10/30
# 2/2 [==============================] - 2s 935ms/step - loss: 0.4933 - accuracy: 0.8358 - val_loss: 1.2452 - val_accuracy: 0.5882
# Epoch 11/30
# 2/2 [==============================] - 2s 916ms/step - loss: 0.4996 - accuracy: 0.8308 - val_loss: 1.2590 - val_accuracy: 0.5882
# Epoch 12/30
# 2/2 [==============================] - 2s 879ms/step - loss: 0.5163 - accuracy: 0.8010 - val_loss: 1.2849 - val_accuracy: 0.5490
# Epoch 13/30
# 2/2 [==============================] - 2s 913ms/step - loss: 0.4704 - accuracy: 0.8507 - val_loss: 1.3095 - val_accuracy: 0.6078
# Epoch 14/30
# 2/2 [==============================] - 2s 920ms/step - loss: 0.4415 - accuracy: 0.8557 - val_loss: 1.2070 - val_accuracy: 0.6471
# Epoch 15/30
# 2/2 [==============================] - 2s 953ms/step - loss: 0.4278 - accuracy: 0.8657 - val_loss: 1.4939 - val_accuracy: 0.5294
# Epoch 16/30
# 2/2 [==============================] - 2s 942ms/step - loss: 0.4057 - accuracy: 0.8657 - val_loss: 1.2441 - val_accuracy: 0.5686
# Epoch 17/30
# 2/2 [==============================] - 2s 903ms/step - loss: 0.3588 - accuracy: 0.9204 - val_loss: 1.2699 - val_accuracy: 0.5490
# Epoch 18/30
# 2/2 [==============================] - 2s 933ms/step - loss: 0.3000 - accuracy: 0.9204 - val_loss: 1.3242 - val_accuracy: 0.5686
# Epoch 19/30
# 2/2 [==============================] - 2s 924ms/step - loss: 0.2877 - accuracy: 0.9303 - val_loss: 1.2951 - val_accuracy: 0.6078
# Epoch 20/30
# 2/2 [==============================] - 2s 933ms/step - loss: 0.2501 - accuracy: 0.9353 - val_loss: 1.4193 - val_accuracy: 0.5294
# Epoch 21/30
# 2/2 [==============================] - 2s 908ms/step - loss: 0.2505 - accuracy: 0.9353 - val_loss: 1.3686 - val_accuracy: 0.6078
# Epoch 22/30
# 2/2 [==============================] - 2s 999ms/step - loss: 0.2113 - accuracy: 0.9502 - val_loss: 1.3992 - val_accuracy: 0.5882
# Epoch 23/30
# 2/2 [==============================] - 2s 979ms/step - loss: 0.1866 - accuracy: 0.9602 - val_loss: 1.5146 - val_accuracy: 0.5686
# Epoch 24/30
# 2/2 [==============================] - 2s 930ms/step - loss: 0.1666 - accuracy: 0.9652 - val_loss: 1.5810 - val_accuracy: 0.5490
# Epoch 25/30
# 2/2 [==============================] - 2s 889ms/step - loss: 0.1491 - accuracy: 0.9701 - val_loss: 1.5469 - val_accuracy: 0.6078
# Epoch 26/30
# 2/2 [==============================] - 2s 889ms/step - loss: 0.1498 - accuracy: 0.9801 - val_loss: 1.6658 - val_accuracy: 0.5490
# Epoch 27/30
# 2/2 [==============================] - 2s 893ms/step - loss: 0.1287 - accuracy: 0.9751 - val_loss: 1.6447 - val_accuracy: 0.6078
# Epoch 28/30
# 2/2 [==============================] - 2s 921ms/step - loss: 0.1173 - accuracy: 0.9701 - val_loss: 1.7107 - val_accuracy: 0.5686
# Epoch 29/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1096 - accuracy: 0.9751 - val_loss: 1.8609 - val_accuracy: 0.5294
# Epoch 30/30
# 2/2 [==============================] - 2s 933ms/step - loss: 0.0947 - accuracy: 0.9751 - val_loss: 1.7020 - val_accuracy: 0.6667

# %%
model.save("Vehicle_Long_Model.h5py")
# Out:
# INFO:tensorflow:Assets written to: Vehicle_Long_Model.h5py\assets
