# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['Boat', 'Bus', 'Cycle','Helicopter','Truck']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['Train', 'Test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading Train
# 100%|██████████| 48/48 [00:00<00:00, 246.77it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1502.45it/s]
# 100%|██████████| 60/60 [00:00<00:00, 1477.37it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1458.52it/s]
# 100%|██████████| 48/48 [00:00<00:00, 1375.06it/s]
# Loading Test
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 252
# Number of testing examples: 0
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)

pd.DataFrame({'train': train_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0,0,0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ##Scale the Data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# ##Create Simple Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 3s 1s/step - loss: 3.2549 - accuracy: 0.1692 - val_loss: 6.9078 - val_accuracy: 0.1569
# Epoch 2/20
# 2/2 [==============================] - 2s 828ms/step - loss: 4.6426 - accuracy: 0.2139 - val_loss: 3.8924 - val_accuracy: 0.1765
# Epoch 3/20
# 2/2 [==============================] - 2s 839ms/step - loss: 2.7435 - accuracy: 0.1940 - val_loss: 1.9798 - val_accuracy: 0.2549
# Epoch 4/20
# 2/2 [==============================] - 2s 929ms/step - loss: 1.7121 - accuracy: 0.2985 - val_loss: 1.6012 - val_accuracy: 0.3137
# Epoch 5/20
# 2/2 [==============================] - 2s 900ms/step - loss: 1.5106 - accuracy: 0.3234 - val_loss: 1.4599 - val_accuracy: 0.3922
# Epoch 6/20
# 2/2 [==============================] - 2s 836ms/step - loss: 1.4305 - accuracy: 0.4577 - val_loss: 1.4217 - val_accuracy: 0.3529
# Epoch 7/20
# 2/2 [==============================] - 2s 873ms/step - loss: 1.3057 - accuracy: 0.4677 - val_loss: 1.3253 - val_accuracy: 0.4902
# Epoch 8/20
# 2/2 [==============================] - 2s 868ms/step - loss: 1.1607 - accuracy: 0.6418 - val_loss: 1.2449 - val_accuracy: 0.5882
# Epoch 9/20
# 2/2 [==============================] - 2s 849ms/step - loss: 0.9828 - accuracy: 0.7363 - val_loss: 1.1807 - val_accuracy: 0.5882
# Epoch 10/20
# 2/2 [==============================] - 2s 838ms/step - loss: 0.8079 - accuracy: 0.8308 - val_loss: 1.1951 - val_accuracy: 0.5294
# Epoch 11/20
# 2/2 [==============================] - 2s 863ms/step - loss: 0.6459 - accuracy: 0.8806 - val_loss: 1.0238 - val_accuracy: 0.5490
# Epoch 12/20
# 2/2 [==============================] - 2s 946ms/step - loss: 0.4802 - accuracy: 0.9453 - val_loss: 1.0182 - val_accuracy: 0.5490
# Epoch 13/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.3739 - accuracy: 0.9154 - val_loss: 0.9252 - val_accuracy: 0.6863
# Epoch 14/20
# 2/2 [==============================] - 2s 856ms/step - loss: 0.2824 - accuracy: 0.9453 - val_loss: 0.9164 - val_accuracy: 0.5882
# Epoch 15/20
# 2/2 [==============================] - 2s 882ms/step - loss: 0.1843 - accuracy: 0.9701 - val_loss: 0.9514 - val_accuracy: 0.6078
# Epoch 16/20
# 2/2 [==============================] - 2s 848ms/step - loss: 0.1351 - accuracy: 0.9900 - val_loss: 0.9058 - val_accuracy: 0.6471
# Epoch 17/20
# 2/2 [==============================] - 2s 852ms/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.6275
# Epoch 18/20
# 2/2 [==============================] - 2s 876ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 1.0452 - val_accuracy: 0.6471
# Epoch 19/20
# 2/2 [==============================] - 2s 820ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 1.1697 - val_accuracy: 0.5686
# Epoch 20/20
# 2/2 [==============================] - 2s 912ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.2211 - val_accuracy: 0.6078

# %%
model.save("Vehicle_Court_Model.h5py")
# Out:
# INFO:tensorflow:Assets written to: Vehicle_Court_Model.h5py\assets
